# %%
import utils

# %%
simulations = [utils.commercial]
plots = [utils.ch_iter_time]
algs = ['gen', 'pso', 'cmaes']

# %%
for alg in algs:
        # %run {alg}.py

# %%
for plot in plots:
    utils.plot('commercial', plot)

# %%
import utils
utils.histogram()
